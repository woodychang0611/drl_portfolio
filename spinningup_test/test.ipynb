# %%
import torch
torch.cuda.current_device()
torch.cuda.get_device_name(0)
from datetime import datetime

# %%
from sderl import ppo_pytorch as ppo
from sderl import sac_pytorch as sac

# %%
import gym

env_fn = lambda : gym.make('MountainCarContinuous-v0')
print("Current time:", datetime.now())
sac(env_fn=env_fn)
print("Current time:", datetime.now())
# Out:
# Current time: 2021-03-01 08:21:10.404112
# Logging data to /tmp/experiments/1614586870/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{},
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "device":	"cuda",
#     "env_fn":	"<function <lambda> at 0x7fe3802c39d8>",
#     "epochs":	100,
#     "gamma":	0.99,
#     "logger":	{
#         "<sderl.utils.logx.EpochLogger object at 0x7fe3802b5048>":	{
#             "epoch_dict":	{},
#             "exp_name":	null,
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/tmp/experiments/1614586870",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/tmp/experiments/1614586870/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{},
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# use GPU
# MLPQFunction(
#   (fe_net): Flatten()
#   (q): Sequential(
#     (0): Linear(in_features=3, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Identity()
#   )
# )
# /opt/conda/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Number of parameters: 	 pi: 67074, 	 q1: 67073, 	 q2: 67073
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -33.3 |
# |          StdEpRet |           0.703 |
# |          MaxEpRet |           -32.4 |
# |          MinEpRet |           -34.3 |
# |  AverageTestEpRet |        -0.00193 |
# |      StdTestEpRet |        0.000848 |
# |      MaxTestEpRet |        -0.00108 |
# |      MinTestEpRet |        -0.00424 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           4e+03 |
# |            LossPi |          -0.897 |
# |             LossQ |         0.00362 |
# |              Time |             125 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -33.7 |
# |          StdEpRet |           0.372 |
# |          MaxEpRet |           -33.2 |
# |          MinEpRet |           -34.2 |
# |  AverageTestEpRet |         -0.0161 |
# |      StdTestEpRet |        1.08e-05 |
# |      MaxTestEpRet |         -0.0161 |
# |      MinTestEpRet |         -0.0161 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           8e+03 |
# |            LossPi |           -2.38 |
# |             LossQ |          0.0116 |
# |              Time |             281 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           -31.6 |
# |          StdEpRet |            1.65 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |           -33.9 |
# |  AverageTestEpRet |         -0.0023 |
# |      StdTestEpRet |        8.05e-06 |
# |      MaxTestEpRet |        -0.00228 |
# |      MinTestEpRet |        -0.00231 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.2e+04 |
# |            LossPi |           -3.76 |
# |             LossQ |          0.0294 |
# |              Time |             443 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.613 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -31.2 |
# |  AverageTestEpRet |        -0.00085 |
# |      StdTestEpRet |        0.000123 |
# |      MaxTestEpRet |       -0.000784 |
# |      MinTestEpRet |         -0.0011 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.6e+04 |
# |            LossPi |           -4.87 |
# |             LossQ |          0.0418 |
# |              Time |             613 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.829 |
# |          MaxEpRet |           -29.3 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |        -0.00605 |
# |      StdTestEpRet |        5.78e-05 |
# |      MaxTestEpRet |        -0.00597 |
# |      MinTestEpRet |         -0.0061 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |           -5.74 |
# |             LossQ |          0.0677 |
# |              Time |             783 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |           -30.6 |
# |          StdEpRet |           0.607 |
# |          MaxEpRet |             -30 |
# |          MinEpRet |           -31.5 |
# |  AverageTestEpRet |         -0.0186 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |         -0.0186 |
# |      MinTestEpRet |         -0.0186 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         2.4e+04 |
# |            LossPi |           -6.42 |
# |             LossQ |          0.0778 |
# |              Time |             952 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |           -29.5 |
# |          StdEpRet |           0.964 |
# |          MaxEpRet |           -28.4 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |         -0.0711 |
# |      StdTestEpRet |         0.00145 |
# |      MaxTestEpRet |         -0.0691 |
# |      MinTestEpRet |         -0.0734 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         2.8e+04 |
# |            LossPi |           -6.94 |
# |             LossQ |          0.0976 |
# |              Time |        1.11e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.695 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |         -0.0596 |
# |      StdTestEpRet |         0.00826 |
# |      MaxTestEpRet |         -0.0511 |
# |      MinTestEpRet |         -0.0791 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.2e+04 |
# |            LossPi |           -7.35 |
# |             LossQ |           0.103 |
# |              Time |        1.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.603 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.5 |
# |  AverageTestEpRet |        -0.00609 |
# |      StdTestEpRet |         0.00516 |
# |      MaxTestEpRet |       -0.000184 |
# |      MinTestEpRet |         -0.0139 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.6e+04 |
# |            LossPi |            -7.7 |
# |             LossQ |           0.108 |
# |              Time |        1.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           -29.8 |
# |          StdEpRet |           0.554 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |         -0.0129 |
# |      StdTestEpRet |         0.00701 |
# |      MaxTestEpRet |        -0.00695 |
# |      MinTestEpRet |         -0.0283 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |           -7.97 |
# |             LossQ |           0.112 |
# |              Time |        1.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -29.5 |
# |          StdEpRet |           0.696 |
# |          MaxEpRet |           -28.8 |
# |          MinEpRet |           -30.5 |
# |  AverageTestEpRet |         -0.0548 |
# |      StdTestEpRet |          0.0126 |
# |      MaxTestEpRet |         -0.0435 |
# |      MinTestEpRet |         -0.0838 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         4.4e+04 |
# |            LossPi |           -8.19 |
# |             LossQ |           0.124 |
# |              Time |        1.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           -29.5 |
# |          StdEpRet |           0.506 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |         -0.0353 |
# |      StdTestEpRet |         0.00701 |
# |      MaxTestEpRet |         -0.0281 |
# |      MinTestEpRet |         -0.0502 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         4.8e+04 |
# |            LossPi |           -8.38 |
# |             LossQ |           0.134 |
# |              Time |        1.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.788 |
# |          MaxEpRet |           -29.3 |
# |          MinEpRet |           -31.5 |
# |  AverageTestEpRet |         -0.0816 |
# |      StdTestEpRet |            0.01 |
# |      MaxTestEpRet |         -0.0722 |
# |      MinTestEpRet |          -0.106 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         5.2e+04 |
# |            LossPi |           -8.53 |
# |             LossQ |           0.141 |
# |              Time |        1.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |           0.365 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |         -0.0105 |
# |      StdTestEpRet |         0.00549 |
# |      MaxTestEpRet |        -0.00325 |
# |      MinTestEpRet |         -0.0192 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         5.6e+04 |
# |            LossPi |           -8.65 |
# |             LossQ |           0.139 |
# |              Time |        1.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |            1.01 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |           -31.5 |
# |  AverageTestEpRet |         -0.0699 |
# |      StdTestEpRet |         0.00268 |
# |      MaxTestEpRet |         -0.0663 |
# |      MinTestEpRet |          -0.075 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |           -8.74 |
# |             LossQ |            0.15 |
# |              Time |        1.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.458 |
# |          MaxEpRet |           -29.8 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |        -0.00256 |
# |      StdTestEpRet |         0.00149 |
# |      MaxTestEpRet |        -0.00119 |
# |      MinTestEpRet |        -0.00658 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         6.4e+04 |
# |            LossPi |           -8.79 |
# |             LossQ |           0.149 |
# |              Time |        1.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |            1.02 |
# |          MaxEpRet |           -28.8 |
# |          MinEpRet |           -31.4 |
# |  AverageTestEpRet |        -0.00943 |
# |      StdTestEpRet |         0.00694 |
# |      MaxTestEpRet |        -0.00261 |
# |      MinTestEpRet |         -0.0261 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         6.8e+04 |
# |            LossPi |           -8.83 |
# |             LossQ |           0.154 |
# |              Time |        1.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |           -31.2 |
# |          StdEpRet |           0.777 |
# |          MaxEpRet |           -30.2 |
# |          MinEpRet |           -32.4 |
# |  AverageTestEpRet |         -0.0369 |
# |      StdTestEpRet |         0.00651 |
# |      MaxTestEpRet |          -0.032 |
# |      MinTestEpRet |         -0.0522 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         7.2e+04 |
# |            LossPi |           -8.86 |
# |             LossQ |            0.15 |
# |              Time |        1.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |           -30.6 |
# |          StdEpRet |           0.935 |
# |          MaxEpRet |           -29.6 |
# |          MinEpRet |           -31.8 |
# |  AverageTestEpRet |         -0.0724 |
# |      StdTestEpRet |         0.00518 |
# |      MaxTestEpRet |         -0.0637 |
# |      MinTestEpRet |         -0.0786 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         7.6e+04 |
# |            LossPi |           -8.92 |
# |             LossQ |           0.152 |
# |              Time |        1.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |            0.29 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -30.1 |
# |  AverageTestEpRet |          -0.129 |
# |      StdTestEpRet |          0.0246 |
# |      MaxTestEpRet |          -0.108 |
# |      MinTestEpRet |          -0.169 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |           -8.98 |
# |             LossQ |           0.142 |
# |              Time |        1.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.681 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -30.7 |
# |  AverageTestEpRet |         -0.0112 |
# |      StdTestEpRet |         0.00215 |
# |      MaxTestEpRet |        -0.00975 |
# |      MinTestEpRet |         -0.0176 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         8.4e+04 |
# |            LossPi |           -9.04 |
# |             LossQ |           0.151 |
# |              Time |        1.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.352 |
# |          MaxEpRet |           -29.8 |
# |          MinEpRet |           -30.7 |
# |  AverageTestEpRet |        -0.00897 |
# |      StdTestEpRet |         0.00315 |
# |      MaxTestEpRet |        -0.00634 |
# |      MinTestEpRet |         -0.0145 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         8.8e+04 |
# |            LossPi |           -9.07 |
# |             LossQ |           0.164 |
# |              Time |        1.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.885 |
# |          MaxEpRet |           -28.1 |
# |          MinEpRet |           -30.2 |
# |  AverageTestEpRet |        -0.00134 |
# |      StdTestEpRet |         0.00111 |
# |      MaxTestEpRet |       -0.000856 |
# |      MinTestEpRet |        -0.00462 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         9.2e+04 |
# |            LossPi |           -9.11 |
# |             LossQ |           0.146 |
# |              Time |        1.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |           -29.5 |
# |          StdEpRet |           0.885 |
# |          MaxEpRet |           -28.3 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |         -0.0061 |
# |      StdTestEpRet |        0.000633 |
# |      MaxTestEpRet |        -0.00579 |
# |      MinTestEpRet |        -0.00789 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         9.6e+04 |
# |            LossPi |           -9.14 |
# |             LossQ |           0.161 |
# |              Time |        1.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |           -30.9 |
# |          StdEpRet |            1.03 |
# |          MaxEpRet |           -29.6 |
# |          MinEpRet |           -32.4 |
# |  AverageTestEpRet |         -0.0185 |
# |      StdTestEpRet |         0.00391 |
# |      MaxTestEpRet |         -0.0162 |
# |      MinTestEpRet |         -0.0275 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           1e+05 |
# |            LossPi |           -9.16 |
# |             LossQ |           0.174 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           -29.5 |
# |          StdEpRet |           0.802 |
# |          MaxEpRet |           -28.7 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |        -0.00182 |
# |      StdTestEpRet |        2.19e-06 |
# |      MaxTestEpRet |        -0.00181 |
# |      MinTestEpRet |        -0.00182 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.04e+05 |
# |            LossPi |           -9.17 |
# |             LossQ |           0.169 |
# |              Time |        1.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.704 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |       -0.000478 |
# |      StdTestEpRet |        0.000803 |
# |      MaxTestEpRet |       -1.19e-05 |
# |      MinTestEpRet |        -0.00262 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.08e+05 |
# |            LossPi |            -9.2 |
# |             LossQ |           0.177 |
# |              Time |        1.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.645 |
# |          MaxEpRet |           -29.6 |
# |          MinEpRet |           -31.2 |
# |  AverageTestEpRet |        -0.00546 |
# |      StdTestEpRet |         0.00437 |
# |      MaxTestEpRet |        -0.00232 |
# |      MinTestEpRet |         -0.0145 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.12e+05 |
# |            LossPi |           -9.21 |
# |             LossQ |           0.165 |
# |              Time |        2.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |           0.611 |
# |          MaxEpRet |             -30 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |        -0.00134 |
# |      StdTestEpRet |         0.00148 |
# |      MaxTestEpRet |       -0.000844 |
# |      MinTestEpRet |        -0.00579 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.16e+05 |
# |            LossPi |           -9.24 |
# |             LossQ |           0.168 |
# |              Time |        2.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |             0.6 |
# |          MaxEpRet |           -29.9 |
# |          MinEpRet |           -31.5 |
# |  AverageTestEpRet |          -0.023 |
# |      StdTestEpRet |        0.000398 |
# |      MaxTestEpRet |         -0.0221 |
# |      MinTestEpRet |         -0.0232 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.2e+05 |
# |            LossPi |           -9.26 |
# |             LossQ |           0.157 |
# |              Time |        2.11e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |           0.784 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |             -32 |
# |  AverageTestEpRet |        -0.00351 |
# |      StdTestEpRet |         0.00114 |
# |      MaxTestEpRet |        -0.00278 |
# |      MinTestEpRet |        -0.00585 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.24e+05 |
# |            LossPi |           -9.28 |
# |             LossQ |           0.161 |
# |              Time |        2.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.551 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |       -0.000991 |
# |      StdTestEpRet |         0.00192 |
# |      MaxTestEpRet |        -3.6e-06 |
# |      MinTestEpRet |        -0.00582 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.28e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.167 |
# |              Time |         2.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.712 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.9 |
# |  AverageTestEpRet |         -0.0235 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |         -0.0235 |
# |      MinTestEpRet |         -0.0235 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.32e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.178 |
# |              Time |        2.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.594 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |        -0.00562 |
# |      StdTestEpRet |         0.00209 |
# |      MaxTestEpRet |        -0.00446 |
# |      MinTestEpRet |         -0.0114 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.36e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.152 |
# |              Time |        2.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |           0.782 |
# |          MaxEpRet |           -30.2 |
# |          MinEpRet |           -32.1 |
# |  AverageTestEpRet |         -0.0156 |
# |      StdTestEpRet |         0.00111 |
# |      MaxTestEpRet |         -0.0142 |
# |      MinTestEpRet |         -0.0177 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.4e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.171 |
# |              Time |        2.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |            1.16 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -32.3 |
# |  AverageTestEpRet |        -0.00157 |
# |      StdTestEpRet |        6.95e-05 |
# |      MaxTestEpRet |        -0.00136 |
# |      MinTestEpRet |         -0.0016 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.44e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.163 |
# |              Time |        2.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |           0.405 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -30.5 |
# |  AverageTestEpRet |       -0.000369 |
# |      StdTestEpRet |        0.000335 |
# |      MaxTestEpRet |       -0.000227 |
# |      MinTestEpRet |        -0.00137 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.48e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.177 |
# |              Time |        2.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.912 |
# |          MaxEpRet |           -29.3 |
# |          MinEpRet |           -31.8 |
# |  AverageTestEpRet |         -0.0624 |
# |      StdTestEpRet |        0.000191 |
# |      MaxTestEpRet |         -0.0618 |
# |      MinTestEpRet |         -0.0625 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.52e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.176 |
# |              Time |        2.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.786 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -31.5 |
# |  AverageTestEpRet |         -0.0298 |
# |      StdTestEpRet |        1.86e-09 |
# |      MaxTestEpRet |         -0.0298 |
# |      MinTestEpRet |         -0.0298 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.56e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.184 |
# |              Time |        2.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.343 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |        -0.00705 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -0.00705 |
# |      MinTestEpRet |        -0.00705 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.6e+05 |
# |            LossPi |           -9.29 |
# |             LossQ |           0.175 |
# |              Time |        2.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.691 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -31.2 |
# |  AverageTestEpRet |        -0.00342 |
# |      StdTestEpRet |        0.000248 |
# |      MaxTestEpRet |        -0.00281 |
# |      MinTestEpRet |        -0.00383 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.64e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.166 |
# |              Time |        2.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.503 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |        -0.00219 |
# |      StdTestEpRet |        8.55e-05 |
# |      MaxTestEpRet |        -0.00193 |
# |      MinTestEpRet |        -0.00222 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.68e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.153 |
# |              Time |        2.62e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |           0.625 |
# |          MaxEpRet |           -29.6 |
# |          MinEpRet |           -31.3 |
# |  AverageTestEpRet |        -0.00796 |
# |      StdTestEpRet |        0.000756 |
# |      MaxTestEpRet |        -0.00769 |
# |      MinTestEpRet |         -0.0102 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.72e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |            0.18 |
# |              Time |        2.67e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |            1.23 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -32.4 |
# |  AverageTestEpRet |          -0.003 |
# |      StdTestEpRet |          0.0013 |
# |      MaxTestEpRet |          -0.002 |
# |      MinTestEpRet |         -0.0053 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.76e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.181 |
# |              Time |        2.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |           0.459 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |        -0.00363 |
# |      StdTestEpRet |         0.00074 |
# |      MaxTestEpRet |        -0.00328 |
# |      MinTestEpRet |        -0.00558 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.8e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.176 |
# |              Time |        2.75e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |           -29.8 |
# |          StdEpRet |             0.7 |
# |          MaxEpRet |           -28.8 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |         -0.0257 |
# |      StdTestEpRet |        0.000908 |
# |      MaxTestEpRet |         -0.0237 |
# |      MinTestEpRet |         -0.0261 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.84e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.165 |
# |              Time |        2.79e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.123 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |           -30.5 |
# |  AverageTestEpRet |         -0.0457 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |         -0.0457 |
# |      MinTestEpRet |         -0.0457 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.88e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.173 |
# |              Time |        2.84e+03 |
# ---------------------------------------
