# %%
import torch
torch.cuda.current_device()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla V100-PCIE-32GB'

# %%
from sderl import ppo_pytorch as ppo
from sderl import sac_pytorch as sac

# %%
import gym

env_fn = lambda : gym.make('MountainCarContinuous-v0')
sac(env_fn=env_fn)
# Out:
# Logging data to /tmp/experiments/1614573634/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{},
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "device":	"cuda",
#     "env_fn":	"<function <lambda> at 0x7f08400548c8>",
#     "epochs":	100,
#     "gamma":	0.99,
#     "logger":	{
#         "<sderl.utils.logx.EpochLogger object at 0x7f0840056b38>":	{
#             "epoch_dict":	{},
#             "exp_name":	null,
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/tmp/experiments/1614573634",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/tmp/experiments/1614573634/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{},
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# use GPU
# MLPQFunction(
#   (fe_net): Flatten()
#   (q): Sequential(
#     (0): Linear(in_features=3, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Identity()
#   )
# )
#
# Number of parameters: 	 pi: 67074, 	 q1: 67073, 	 q2: 67073
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -32.9 |
# |          StdEpRet |           0.666 |
# |          MaxEpRet |           -32.2 |
# |          MinEpRet |           -33.8 |
# |  AverageTestEpRet |        -0.00799 |
# |      StdTestEpRet |        6.17e-05 |
# |      MaxTestEpRet |        -0.00782 |
# |      MinTestEpRet |        -0.00805 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           4e+03 |
# |            LossPi |          -0.898 |
# |             LossQ |         0.00362 |
# |              Time |            34.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -32.4 |
# |          StdEpRet |           0.403 |
# |          MaxEpRet |             -32 |
# |          MinEpRet |           -33.1 |
# |  AverageTestEpRet |        -0.00121 |
# |      StdTestEpRet |        4.05e-06 |
# |      MaxTestEpRet |        -0.00121 |
# |      MinTestEpRet |        -0.00122 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           8e+03 |
# |            LossPi |           -2.38 |
# |             LossQ |           0.012 |
# |              Time |            76.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           -32.3 |
# |          StdEpRet |            2.47 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |           -35.2 |
# |  AverageTestEpRet |         -0.0113 |
# |      StdTestEpRet |        1.12e-05 |
# |      MaxTestEpRet |         -0.0113 |
# |      MinTestEpRet |         -0.0114 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.2e+04 |
# |            LossPi |           -3.76 |
# |             LossQ |          0.0301 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.607 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |           -31.4 |
# |  AverageTestEpRet |       -0.000585 |
# |      StdTestEpRet |        7.35e-05 |
# |      MaxTestEpRet |       -0.000538 |
# |      MinTestEpRet |       -0.000731 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.6e+04 |
# |            LossPi |           -4.86 |
# |             LossQ |          0.0426 |
# |              Time |             164 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.806 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -31.7 |
# |  AverageTestEpRet |         -0.0141 |
# |      StdTestEpRet |        6.45e-05 |
# |      MaxTestEpRet |         -0.0141 |
# |      MinTestEpRet |         -0.0142 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |           -5.73 |
# |             LossQ |          0.0683 |
# |              Time |             212 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |           0.538 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |           -31.4 |
# |  AverageTestEpRet |        -0.00993 |
# |      StdTestEpRet |        0.000399 |
# |      MaxTestEpRet |        -0.00946 |
# |      MinTestEpRet |         -0.0105 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         2.4e+04 |
# |            LossPi |           -6.42 |
# |             LossQ |          0.0777 |
# |              Time |             257 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.889 |
# |          MaxEpRet |           -28.4 |
# |          MinEpRet |           -30.9 |
# |  AverageTestEpRet |        -0.00262 |
# |      StdTestEpRet |         0.00129 |
# |      MaxTestEpRet |       -0.000996 |
# |      MinTestEpRet |        -0.00519 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         2.8e+04 |
# |            LossPi |           -6.98 |
# |             LossQ |           0.101 |
# |              Time |             301 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.725 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -31.1 |
# |  AverageTestEpRet |         -0.0045 |
# |      StdTestEpRet |         0.00258 |
# |      MaxTestEpRet |        -0.00213 |
# |      MinTestEpRet |          -0.011 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.2e+04 |
# |            LossPi |           -7.41 |
# |             LossQ |           0.108 |
# |              Time |             345 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.579 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |        -0.00291 |
# |      StdTestEpRet |         0.00119 |
# |      MaxTestEpRet |        -0.00156 |
# |      MinTestEpRet |        -0.00476 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.6e+04 |
# |            LossPi |           -7.76 |
# |             LossQ |           0.114 |
# |              Time |             389 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.633 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.5 |
# |  AverageTestEpRet |         -0.0296 |
# |      StdTestEpRet |         0.00203 |
# |      MaxTestEpRet |         -0.0278 |
# |      MinTestEpRet |         -0.0341 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |           -8.04 |
# |             LossQ |           0.118 |
# |              Time |             432 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.729 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -30.7 |
# |  AverageTestEpRet |          -0.155 |
# |      StdTestEpRet |         0.00545 |
# |      MaxTestEpRet |           -0.15 |
# |      MinTestEpRet |          -0.167 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         4.4e+04 |
# |            LossPi |           -8.26 |
# |             LossQ |           0.131 |
# |              Time |             479 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.499 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |         -0.0515 |
# |      StdTestEpRet |         0.00401 |
# |      MaxTestEpRet |         -0.0474 |
# |      MinTestEpRet |         -0.0606 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         4.8e+04 |
# |            LossPi |           -8.45 |
# |             LossQ |            0.14 |
# |              Time |             527 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |            0.84 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -31.7 |
# |  AverageTestEpRet |         -0.0784 |
# |      StdTestEpRet |         0.00516 |
# |      MaxTestEpRet |         -0.0738 |
# |      MinTestEpRet |          -0.091 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         5.2e+04 |
# |            LossPi |           -8.59 |
# |             LossQ |           0.146 |
# |              Time |             570 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |           0.365 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |        -0.00774 |
# |      StdTestEpRet |         0.00251 |
# |      MaxTestEpRet |        -0.00462 |
# |      MinTestEpRet |          -0.012 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         5.6e+04 |
# |            LossPi |           -8.71 |
# |             LossQ |           0.143 |
# |              Time |             613 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |            1.03 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |           -31.4 |
# |  AverageTestEpRet |         -0.0176 |
# |      StdTestEpRet |         0.00278 |
# |      MaxTestEpRet |         -0.0138 |
# |      MinTestEpRet |         -0.0226 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |           -8.82 |
# |             LossQ |           0.156 |
# |              Time |             656 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.517 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |       -0.000994 |
# |      StdTestEpRet |        0.000979 |
# |      MaxTestEpRet |       -6.01e-07 |
# |      MinTestEpRet |         -0.0035 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         6.4e+04 |
# |            LossPi |            -8.9 |
# |             LossQ |           0.153 |
# |              Time |             700 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.943 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -31.3 |
# |  AverageTestEpRet |          -0.072 |
# |      StdTestEpRet |         0.00519 |
# |      MaxTestEpRet |         -0.0678 |
# |      MinTestEpRet |         -0.0851 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         6.8e+04 |
# |            LossPi |           -8.95 |
# |             LossQ |           0.161 |
# |              Time |             745 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |           -31.2 |
# |          StdEpRet |           0.763 |
# |          MaxEpRet |           -30.4 |
# |          MinEpRet |           -32.4 |
# |  AverageTestEpRet |        -0.00707 |
# |      StdTestEpRet |         0.00683 |
# |      MaxTestEpRet |        -0.00185 |
# |      MinTestEpRet |         -0.0224 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         7.2e+04 |
# |            LossPi |           -8.98 |
# |             LossQ |           0.154 |
# |              Time |             789 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |           -30.6 |
# |          StdEpRet |           0.918 |
# |          MaxEpRet |           -29.6 |
# |          MinEpRet |           -31.7 |
# |  AverageTestEpRet |        -0.00114 |
# |      StdTestEpRet |        0.000983 |
# |      MaxTestEpRet |       -7.52e-05 |
# |      MinTestEpRet |        -0.00326 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         7.6e+04 |
# |            LossPi |           -8.98 |
# |             LossQ |           0.157 |
# |              Time |             832 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.267 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |             -30 |
# |  AverageTestEpRet |         -0.0398 |
# |      StdTestEpRet |          0.0115 |
# |      MaxTestEpRet |         -0.0277 |
# |      MinTestEpRet |         -0.0588 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |           -9.01 |
# |             LossQ |           0.145 |
# |              Time |             878 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |           0.664 |
# |          MaxEpRet |           -28.8 |
# |          MinEpRet |           -30.5 |
# |  AverageTestEpRet |        -0.00327 |
# |      StdTestEpRet |         0.00361 |
# |      MaxTestEpRet |       -0.000146 |
# |      MinTestEpRet |         -0.0126 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         8.4e+04 |
# |            LossPi |           -9.04 |
# |             LossQ |           0.153 |
# |              Time |             922 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.299 |
# |          MaxEpRet |           -29.9 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |         -0.0508 |
# |      StdTestEpRet |         0.00392 |
# |      MaxTestEpRet |         -0.0459 |
# |      MinTestEpRet |         -0.0571 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         8.8e+04 |
# |            LossPi |           -9.04 |
# |             LossQ |           0.166 |
# |              Time |             965 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.917 |
# |          MaxEpRet |             -28 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |        -0.00349 |
# |      StdTestEpRet |          0.0026 |
# |      MaxTestEpRet |        -0.00151 |
# |      MinTestEpRet |         -0.0103 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         9.2e+04 |
# |            LossPi |           -9.05 |
# |             LossQ |           0.146 |
# |              Time |        1.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.873 |
# |          MaxEpRet |           -28.5 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |        -0.00516 |
# |      StdTestEpRet |        0.000948 |
# |      MaxTestEpRet |        -0.00456 |
# |      MinTestEpRet |        -0.00776 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         9.6e+04 |
# |            LossPi |           -9.05 |
# |             LossQ |           0.163 |
# |              Time |        1.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |           -30.9 |
# |          StdEpRet |            1.08 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -32.4 |
# |  AverageTestEpRet |          -0.022 |
# |      StdTestEpRet |         0.00232 |
# |      MaxTestEpRet |         -0.0205 |
# |      MinTestEpRet |         -0.0275 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           1e+05 |
# |            LossPi |           -9.05 |
# |             LossQ |           0.171 |
# |              Time |         1.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |            0.88 |
# |          MaxEpRet |           -28.7 |
# |          MinEpRet |           -31.1 |
# |  AverageTestEpRet |        -0.00185 |
# |      StdTestEpRet |          0.0012 |
# |      MaxTestEpRet |       -0.000274 |
# |      MinTestEpRet |        -0.00388 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.04e+05 |
# |            LossPi |           -9.06 |
# |             LossQ |           0.169 |
# |              Time |        1.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.702 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |        -0.00462 |
# |      StdTestEpRet |         0.00181 |
# |      MaxTestEpRet |        -0.00246 |
# |      MinTestEpRet |        -0.00787 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.08e+05 |
# |            LossPi |           -9.07 |
# |             LossQ |           0.175 |
# |              Time |        1.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.559 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |         -0.0347 |
# |      StdTestEpRet |         0.00272 |
# |      MaxTestEpRet |         -0.0308 |
# |      MinTestEpRet |         -0.0391 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.12e+05 |
# |            LossPi |           -9.08 |
# |             LossQ |           0.161 |
# |              Time |        1.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |           0.638 |
# |          MaxEpRet |           -29.8 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |         -0.0335 |
# |      StdTestEpRet |          0.0022 |
# |      MaxTestEpRet |         -0.0322 |
# |      MinTestEpRet |         -0.0398 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.16e+05 |
# |            LossPi |            -9.1 |
# |             LossQ |           0.164 |
# |              Time |        1.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.666 |
# |          MaxEpRet |             -30 |
# |          MinEpRet |           -31.7 |
# |  AverageTestEpRet |         -0.0202 |
# |      StdTestEpRet |         0.00404 |
# |      MaxTestEpRet |         -0.0151 |
# |      MinTestEpRet |         -0.0275 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.2e+05 |
# |            LossPi |           -9.12 |
# |             LossQ |           0.153 |
# |              Time |        1.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |           0.772 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |             -32 |
# |  AverageTestEpRet |        -0.00564 |
# |      StdTestEpRet |         0.00339 |
# |      MaxTestEpRet |        -0.00243 |
# |      MinTestEpRet |         -0.0114 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.24e+05 |
# |            LossPi |           -9.15 |
# |             LossQ |           0.157 |
# |              Time |        1.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |           0.427 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |         -0.0134 |
# |      StdTestEpRet |         0.00428 |
# |      MaxTestEpRet |        -0.00928 |
# |      MinTestEpRet |         -0.0228 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.28e+05 |
# |            LossPi |           -9.18 |
# |             LossQ |           0.164 |
# |              Time |        1.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.708 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -30.9 |
# |  AverageTestEpRet |          -0.086 |
# |      StdTestEpRet |         0.00649 |
# |      MaxTestEpRet |         -0.0746 |
# |      MinTestEpRet |         -0.0989 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.32e+05 |
# |            LossPi |           -9.19 |
# |             LossQ |           0.174 |
# |              Time |        1.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |           0.755 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |        -0.00325 |
# |      StdTestEpRet |         0.00338 |
# |      MaxTestEpRet |       -0.000113 |
# |      MinTestEpRet |         -0.0103 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.36e+05 |
# |            LossPi |           -9.21 |
# |             LossQ |           0.151 |
# |              Time |         1.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |           0.874 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |           -32.3 |
# |  AverageTestEpRet |         -0.0282 |
# |      StdTestEpRet |         0.00436 |
# |      MaxTestEpRet |         -0.0232 |
# |      MinTestEpRet |         -0.0367 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.4e+05 |
# |            LossPi |           -9.23 |
# |             LossQ |           0.169 |
# |              Time |        1.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |             1.1 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -32.3 |
# |  AverageTestEpRet |         -0.0101 |
# |      StdTestEpRet |         0.00114 |
# |      MaxTestEpRet |        -0.00834 |
# |      MinTestEpRet |         -0.0113 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.44e+05 |
# |            LossPi |           -9.23 |
# |             LossQ |           0.162 |
# |              Time |        1.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.451 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -30.7 |
# |  AverageTestEpRet |         -0.0323 |
# |      StdTestEpRet |         0.00385 |
# |      MaxTestEpRet |         -0.0282 |
# |      MinTestEpRet |         -0.0383 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.48e+05 |
# |            LossPi |           -9.24 |
# |             LossQ |           0.176 |
# |              Time |        1.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.941 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -31.8 |
# |  AverageTestEpRet |         -0.0676 |
# |      StdTestEpRet |         0.00206 |
# |      MaxTestEpRet |         -0.0633 |
# |      MinTestEpRet |         -0.0699 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.52e+05 |
# |            LossPi |           -9.23 |
# |             LossQ |           0.175 |
# |              Time |        1.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.745 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -31.4 |
# |  AverageTestEpRet |         -0.0536 |
# |      StdTestEpRet |         0.00485 |
# |      MaxTestEpRet |         -0.0488 |
# |      MinTestEpRet |         -0.0613 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.56e+05 |
# |            LossPi |           -9.23 |
# |             LossQ |           0.183 |
# |              Time |        1.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.435 |
# |          MaxEpRet |           -29.9 |
# |          MinEpRet |           -31.1 |
# |  AverageTestEpRet |         -0.0101 |
# |      StdTestEpRet |         0.00479 |
# |      MaxTestEpRet |         -0.0049 |
# |      MinTestEpRet |         -0.0181 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.6e+05 |
# |            LossPi |           -9.23 |
# |             LossQ |           0.174 |
# |              Time |        1.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.667 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |         -0.0262 |
# |      StdTestEpRet |        0.000552 |
# |      MaxTestEpRet |         -0.0252 |
# |      MinTestEpRet |         -0.0271 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.64e+05 |
# |            LossPi |           -9.24 |
# |             LossQ |           0.165 |
# |              Time |        1.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.479 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |         -0.0289 |
# |      StdTestEpRet |         0.00254 |
# |      MaxTestEpRet |         -0.0256 |
# |      MinTestEpRet |         -0.0343 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.68e+05 |
# |            LossPi |           -9.26 |
# |             LossQ |           0.153 |
# |              Time |        1.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |           -30.6 |
# |          StdEpRet |           0.634 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -31.1 |
# |  AverageTestEpRet |          -0.055 |
# |      StdTestEpRet |        0.000747 |
# |      MaxTestEpRet |         -0.0544 |
# |      MinTestEpRet |         -0.0564 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.72e+05 |
# |            LossPi |           -9.28 |
# |             LossQ |            0.18 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |            1.15 |
# |          MaxEpRet |           -29.3 |
# |          MinEpRet |           -32.4 |
# |  AverageTestEpRet |         -0.0139 |
# |      StdTestEpRet |         0.00637 |
# |      MaxTestEpRet |        -0.00849 |
# |      MinTestEpRet |          -0.024 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.76e+05 |
# |            LossPi |           -9.27 |
# |             LossQ |            0.18 |
# |              Time |        1.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |           0.442 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |        -0.00378 |
# |      StdTestEpRet |         0.00208 |
# |      MaxTestEpRet |        -0.00237 |
# |      MinTestEpRet |        -0.00833 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         1.8e+05 |
# |            LossPi |           -9.28 |
# |             LossQ |           0.175 |
# |              Time |           2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |           0.703 |
# |          MaxEpRet |           -28.7 |
# |          MinEpRet |           -30.7 |
# |  AverageTestEpRet |         -0.0562 |
# |      StdTestEpRet |         0.00642 |
# |      MaxTestEpRet |         -0.0485 |
# |      MinTestEpRet |         -0.0661 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.84e+05 |
# |            LossPi |           -9.29 |
# |             LossQ |           0.165 |
# |              Time |        2.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |          0.0463 |
# |          MaxEpRet |           -30.2 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |        -0.00618 |
# |      StdTestEpRet |         0.00499 |
# |      MaxTestEpRet |       -0.000931 |
# |      MinTestEpRet |         -0.0151 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.88e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.173 |
# |              Time |        2.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.416 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |         -0.0095 |
# |      StdTestEpRet |         0.00155 |
# |      MaxTestEpRet |        -0.00823 |
# |      MinTestEpRet |         -0.0135 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.92e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.178 |
# |              Time |        2.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.263 |
# |          MaxEpRet |           -29.9 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |         -0.0232 |
# |      StdTestEpRet |         0.00191 |
# |      MaxTestEpRet |         -0.0196 |
# |      MinTestEpRet |         -0.0246 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        1.96e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.162 |
# |              Time |        2.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |           -30.6 |
# |          StdEpRet |           0.894 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -31.9 |
# |  AverageTestEpRet |         -0.0092 |
# |      StdTestEpRet |         0.00791 |
# |      MaxTestEpRet |       -0.000106 |
# |      MinTestEpRet |         -0.0209 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           2e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.157 |
# |              Time |        2.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |           -29.4 |
# |          StdEpRet |           0.264 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -29.7 |
# |  AverageTestEpRet |         -0.0255 |
# |      StdTestEpRet |        0.000588 |
# |      MaxTestEpRet |         -0.0247 |
# |      MinTestEpRet |         -0.0265 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.04e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.182 |
# |              Time |        2.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.774 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -31.5 |
# |  AverageTestEpRet |         -0.0165 |
# |      StdTestEpRet |         0.00514 |
# |      MaxTestEpRet |         -0.0115 |
# |      MinTestEpRet |         -0.0283 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.08e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.195 |
# |              Time |         2.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |            0.39 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |         -0.0222 |
# |      StdTestEpRet |          0.0011 |
# |      MaxTestEpRet |          -0.019 |
# |      MinTestEpRet |         -0.0227 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.12e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.166 |
# |              Time |        2.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |           0.507 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |         -0.0264 |
# |      StdTestEpRet |         0.00317 |
# |      MaxTestEpRet |         -0.0206 |
# |      MinTestEpRet |         -0.0287 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.16e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.177 |
# |              Time |        2.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |           -30.9 |
# |          StdEpRet |            0.98 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -31.8 |
# |  AverageTestEpRet |        -0.00565 |
# |      StdTestEpRet |         0.00427 |
# |      MaxTestEpRet |       -0.000575 |
# |      MinTestEpRet |          -0.014 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         2.2e+05 |
# |            LossPi |           -9.33 |
# |             LossQ |           0.175 |
# |              Time |        2.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              56 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.765 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |         -0.0141 |
# |      StdTestEpRet |         0.00329 |
# |      MaxTestEpRet |         -0.0115 |
# |      MinTestEpRet |         -0.0213 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.24e+05 |
# |            LossPi |           -9.33 |
# |             LossQ |           0.173 |
# |              Time |        2.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              57 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |            1.05 |
# |          MaxEpRet |           -28.7 |
# |          MinEpRet |           -31.4 |
# |  AverageTestEpRet |         -0.0388 |
# |      StdTestEpRet |         0.00269 |
# |      MaxTestEpRet |         -0.0353 |
# |      MinTestEpRet |         -0.0429 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.28e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.171 |
# |              Time |        2.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              58 |
# |      AverageEpRet |           -29.8 |
# |          StdEpRet |           0.986 |
# |          MaxEpRet |           -28.2 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |        -0.00786 |
# |      StdTestEpRet |         0.00384 |
# |      MaxTestEpRet |        -0.00425 |
# |      MinTestEpRet |         -0.0148 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.32e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.167 |
# |              Time |        2.57e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              59 |
# |      AverageEpRet |           -29.8 |
# |          StdEpRet |           0.689 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -30.9 |
# |  AverageTestEpRet |         -0.0346 |
# |      StdTestEpRet |         0.00196 |
# |      MaxTestEpRet |         -0.0322 |
# |      MinTestEpRet |         -0.0379 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.36e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.176 |
# |              Time |        2.62e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              60 |
# |      AverageEpRet |           -29.6 |
# |          StdEpRet |            0.72 |
# |          MaxEpRet |           -28.6 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |        -0.00874 |
# |      StdTestEpRet |         0.00732 |
# |      MaxTestEpRet |        -0.00192 |
# |      MinTestEpRet |          -0.024 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         2.4e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.165 |
# |              Time |        2.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              61 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |            1.03 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -31.8 |
# |  AverageTestEpRet |         -0.0218 |
# |      StdTestEpRet |         0.00183 |
# |      MaxTestEpRet |         -0.0199 |
# |      MinTestEpRet |         -0.0257 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.44e+05 |
# |            LossPi |           -9.35 |
# |             LossQ |           0.172 |
# |              Time |        2.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              62 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.456 |
# |          MaxEpRet |           -29.8 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |        -0.00508 |
# |      StdTestEpRet |         0.00207 |
# |      MaxTestEpRet |        -0.00238 |
# |      MinTestEpRet |        -0.00832 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.48e+05 |
# |            LossPi |           -9.35 |
# |             LossQ |            0.17 |
# |              Time |        2.75e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              63 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |           0.737 |
# |          MaxEpRet |           -28.5 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |        -0.00577 |
# |      StdTestEpRet |         0.00495 |
# |      MaxTestEpRet |       -0.000988 |
# |      MinTestEpRet |         -0.0159 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.52e+05 |
# |            LossPi |           -9.35 |
# |             LossQ |           0.179 |
# |              Time |         2.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              64 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |            1.16 |
# |          MaxEpRet |           -28.2 |
# |          MinEpRet |           -31.2 |
# |  AverageTestEpRet |         -0.0332 |
# |      StdTestEpRet |         0.00233 |
# |      MaxTestEpRet |           -0.03 |
# |      MinTestEpRet |         -0.0358 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.56e+05 |
# |            LossPi |           -9.34 |
# |             LossQ |           0.169 |
# |              Time |        2.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              65 |
# |      AverageEpRet |           -30.6 |
# |          StdEpRet |            1.02 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |         -0.0103 |
# |      StdTestEpRet |         0.00488 |
# |      MaxTestEpRet |        -0.00566 |
# |      MinTestEpRet |         -0.0215 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         2.6e+05 |
# |            LossPi |           -9.33 |
# |             LossQ |           0.181 |
# |              Time |        2.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              66 |
# |      AverageEpRet |           -30.2 |
# |          StdEpRet |             0.7 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |         -0.0357 |
# |      StdTestEpRet |         0.00912 |
# |      MaxTestEpRet |         -0.0269 |
# |      MinTestEpRet |         -0.0527 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.64e+05 |
# |            LossPi |           -9.33 |
# |             LossQ |           0.185 |
# |              Time |        2.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              67 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |           0.348 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |        -0.00795 |
# |      StdTestEpRet |        0.000638 |
# |      MaxTestEpRet |        -0.00702 |
# |      MinTestEpRet |        -0.00861 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.68e+05 |
# |            LossPi |           -9.33 |
# |             LossQ |           0.177 |
# |              Time |        2.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              68 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.374 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |        -0.00492 |
# |      StdTestEpRet |         0.00415 |
# |      MaxTestEpRet |        -0.00216 |
# |      MinTestEpRet |         -0.0137 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        2.72e+05 |
# |            LossPi |           -9.33 |
# |             LossQ |           0.159 |
# |              Time |        3.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              69 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |            1.38 |
# |          MaxEpRet |           -28.6 |
# |          MinEpRet |           -32.2 |
# |  AverageTestEpRet |         -0.0151 |
# ...
# |      MaxTestEpRet |         -0.0434 |
# |      MinTestEpRet |         -0.0684 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.08e+05 |
# |            LossPi |           -9.29 |
# |             LossQ |           0.176 |
# |              Time |        3.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              78 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |            1.03 |
# |          MaxEpRet |           -28.3 |
# |          MinEpRet |           -30.9 |
# |  AverageTestEpRet |         -0.0106 |
# |      StdTestEpRet |        0.000668 |
# |      MaxTestEpRet |        -0.00963 |
# |      MinTestEpRet |         -0.0117 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.12e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.163 |
# |              Time |        3.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              79 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.595 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |           -31.1 |
# |  AverageTestEpRet |         -0.0149 |
# |      StdTestEpRet |         0.00334 |
# |      MaxTestEpRet |         -0.0115 |
# |      MinTestEpRet |         -0.0217 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.16e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.173 |
# |              Time |         3.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              80 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |             0.8 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |           -31.1 |
# |  AverageTestEpRet |        -0.00711 |
# |      StdTestEpRet |         0.00556 |
# |      MaxTestEpRet |         -0.0011 |
# |      MinTestEpRet |         -0.0179 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.2e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.176 |
# |              Time |        3.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              81 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |           0.621 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |          -0.013 |
# |      StdTestEpRet |         0.00553 |
# |      MaxTestEpRet |        -0.00654 |
# |      MinTestEpRet |         -0.0258 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.24e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.183 |
# |              Time |        3.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |            1.17 |
# |          MaxEpRet |           -29.3 |
# |          MinEpRet |           -32.1 |
# |  AverageTestEpRet |         -0.0365 |
# |      StdTestEpRet |         0.00299 |
# |      MaxTestEpRet |         -0.0327 |
# |      MinTestEpRet |          -0.043 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.28e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.178 |
# |              Time |        3.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |            1.09 |
# |          MaxEpRet |           -29.9 |
# |          MinEpRet |           -32.6 |
# |  AverageTestEpRet |         -0.0136 |
# |      StdTestEpRet |         0.00734 |
# |      MaxTestEpRet |        -0.00642 |
# |      MinTestEpRet |         -0.0279 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.32e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.165 |
# |              Time |        3.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |            1.09 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |           -31.7 |
# |  AverageTestEpRet |          -0.019 |
# |      StdTestEpRet |         0.00661 |
# |      MaxTestEpRet |         -0.0147 |
# |      MinTestEpRet |         -0.0329 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.36e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.172 |
# |              Time |        3.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.901 |
# |          MaxEpRet |           -28.8 |
# |          MinEpRet |           -31.3 |
# |  AverageTestEpRet |          -0.022 |
# |      StdTestEpRet |           0.004 |
# |      MaxTestEpRet |         -0.0168 |
# |      MinTestEpRet |         -0.0298 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.4e+05 |
# |            LossPi |           -9.31 |
# |             LossQ |           0.166 |
# |              Time |        3.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |           0.739 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |           -31.2 |
# |  AverageTestEpRet |          -0.011 |
# |      StdTestEpRet |        0.000796 |
# |      MaxTestEpRet |        -0.00981 |
# |      MinTestEpRet |         -0.0121 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.44e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.159 |
# |              Time |        3.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.958 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |         -0.0149 |
# |      StdTestEpRet |         0.00266 |
# |      MaxTestEpRet |         -0.0131 |
# |      MinTestEpRet |         -0.0207 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.48e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.176 |
# |              Time |        3.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |           0.733 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |         -0.0205 |
# |      StdTestEpRet |        0.000867 |
# |      MaxTestEpRet |         -0.0197 |
# |      MinTestEpRet |         -0.0219 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.52e+05 |
# |            LossPi |           -9.32 |
# |             LossQ |           0.162 |
# |              Time |         3.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |           -29.7 |
# |          StdEpRet |           0.903 |
# |          MaxEpRet |           -28.2 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |         -0.0408 |
# |      StdTestEpRet |         0.00545 |
# |      MaxTestEpRet |         -0.0375 |
# |      MinTestEpRet |          -0.053 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.56e+05 |
# |            LossPi |            -9.3 |
# |             LossQ |           0.182 |
# |              Time |        3.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |           -30.7 |
# |          StdEpRet |           0.694 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |           -31.3 |
# |  AverageTestEpRet |          -0.103 |
# |      StdTestEpRet |         0.00841 |
# |      MaxTestEpRet |         -0.0937 |
# |      MinTestEpRet |          -0.118 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.6e+05 |
# |            LossPi |           -9.28 |
# |             LossQ |           0.162 |
# |              Time |        3.99e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |           -30.9 |
# |          StdEpRet |           0.439 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |           -31.2 |
# |  AverageTestEpRet |         -0.0757 |
# |      StdTestEpRet |         0.00969 |
# |      MaxTestEpRet |         -0.0678 |
# |      MinTestEpRet |         -0.0942 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.64e+05 |
# |            LossPi |           -9.28 |
# |             LossQ |           0.161 |
# |              Time |        4.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |            0.57 |
# |          MaxEpRet |           -29.1 |
# |          MinEpRet |           -30.7 |
# |  AverageTestEpRet |         -0.0611 |
# |      StdTestEpRet |         0.00357 |
# |      MaxTestEpRet |         -0.0552 |
# |      MinTestEpRet |         -0.0657 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.68e+05 |
# |            LossPi |           -9.27 |
# |             LossQ |           0.181 |
# |              Time |        4.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |             -30 |
# |          StdEpRet |           0.536 |
# |          MaxEpRet |           -29.2 |
# |          MinEpRet |           -30.7 |
# |  AverageTestEpRet |         -0.0465 |
# |      StdTestEpRet |         0.00222 |
# |      MaxTestEpRet |         -0.0436 |
# |      MinTestEpRet |         -0.0498 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.72e+05 |
# |            LossPi |           -9.28 |
# |             LossQ |           0.175 |
# |              Time |        4.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |           -30.8 |
# |          StdEpRet |           0.685 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |           -31.8 |
# |  AverageTestEpRet |         -0.0131 |
# |      StdTestEpRet |         0.00738 |
# |      MaxTestEpRet |        -0.00572 |
# |      MinTestEpRet |         -0.0286 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.76e+05 |
# |            LossPi |           -9.28 |
# |             LossQ |           0.161 |
# |              Time |        4.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |           -30.1 |
# |          StdEpRet |            1.26 |
# |          MaxEpRet |           -28.5 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |         -0.0111 |
# |      StdTestEpRet |         0.00336 |
# |      MaxTestEpRet |        -0.00777 |
# |      MinTestEpRet |         -0.0164 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |         3.8e+05 |
# |            LossPi |           -9.29 |
# |             LossQ |           0.162 |
# |              Time |        4.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |           -30.5 |
# |          StdEpRet |           0.717 |
# |          MaxEpRet |           -29.6 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |         -0.0243 |
# |      StdTestEpRet |         0.00138 |
# |      MaxTestEpRet |         -0.0228 |
# |      MinTestEpRet |         -0.0263 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.84e+05 |
# |            LossPi |           -9.29 |
# |             LossQ |           0.177 |
# |              Time |        4.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |           -30.3 |
# |          StdEpRet |            1.37 |
# |          MaxEpRet |           -28.3 |
# |          MinEpRet |             -32 |
# |  AverageTestEpRet |         -0.0221 |
# |      StdTestEpRet |         0.00295 |
# |      MaxTestEpRet |         -0.0196 |
# |      MinTestEpRet |         -0.0302 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.88e+05 |
# |            LossPi |           -9.27 |
# |             LossQ |           0.185 |
# |              Time |         4.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |           -30.4 |
# |          StdEpRet |           0.897 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |        -0.00566 |
# |      StdTestEpRet |         0.00617 |
# |      MaxTestEpRet |       -0.000517 |
# |      MinTestEpRet |          -0.018 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.92e+05 |
# |            LossPi |           -9.26 |
# |             LossQ |           0.192 |
# |              Time |        4.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |           -29.5 |
# |          StdEpRet |           0.861 |
# |          MaxEpRet |           -28.4 |
# |          MinEpRet |           -30.8 |
# |  AverageTestEpRet |         -0.0835 |
# |      StdTestEpRet |         0.00919 |
# |      MaxTestEpRet |          -0.076 |
# |      MinTestEpRet |          -0.102 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |        3.96e+05 |
# |            LossPi |           -9.26 |
# |             LossQ |           0.177 |
# |              Time |        4.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |           -29.8 |
# |          StdEpRet |           0.648 |
# |          MaxEpRet |           -28.8 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |         -0.0295 |
# |      StdTestEpRet |         0.00167 |
# |      MaxTestEpRet |         -0.0265 |
# |      MinTestEpRet |          -0.032 |
# |             EpLen |             999 |
# |         TestEpLen |             999 |
# | TotalEnvInteracts |           4e+05 |
# |            LossPi |           -9.26 |
# |             LossQ |            0.19 |
# |              Time |        4.44e+03 |
# ---------------------------------------
